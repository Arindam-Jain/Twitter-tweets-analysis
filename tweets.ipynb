# %%
import pandas as pd

# %%
train=pd.read_csv('train.csv')

# %%
test=pd.read_csv('test.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
# id          7613 non-null int64
# keyword     7552 non-null object
# location    5080 non-null object
# text        7613 non-null object
# target      7613 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
train.head(50)
# Out:
#     id keyword                       location  \
# 0    1     NaN                            NaN
# 1    4     NaN                            NaN
# 2    5     NaN                            NaN
# 3    6     NaN                            NaN
# 4    7     NaN                            NaN
# 5    8     NaN                            NaN
# 6   10     NaN                            NaN
# 7   13     NaN                            NaN
# 8   14     NaN                            NaN
# 9   15     NaN                            NaN
# 10  16     NaN                            NaN
# 11  17     NaN                            NaN
# 12  18     NaN                            NaN
# 13  19     NaN                            NaN
# 14  20     NaN                            NaN
# 15  23     NaN                            NaN
# 16  24     NaN                            NaN
# 17  25     NaN                            NaN
# 18  26     NaN                            NaN
# ...

# %%
train['keyword'].value_counts().head()
# Out:
# fatalities     45
# deluge         42
# armageddon     42
# harm           41
# body%20bags    41
# Name: keyword, dtype: int64

# %%
train['location'].value_counts().head(10)
# Out:
# USA                104
# New York            71
# United States       50
# London              45
# Canada              29
# Nigeria             28
# UK                  27
# Los Angeles, CA     26
# India               24
# Mumbai              22
# Name: location, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
sns.countplot(x='target',data=train)

# %%
train.isnull().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
train.drop('location',axis=1,inplace=True)

# %%
train['keyword'].head(50)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31    ablaze
# 32    ablaze
# 33    ablaze
# 34    ablaze
# 35    ablaze
# 36    ablaze
# 37    ablaze
# 38    ablaze
# 39    ablaze
# 40    ablaze
# 41    ablaze
# 42    ablaze
# 43    ablaze
# 44    ablaze
# 45    ablaze
# 46    ablaze
# 47    ablaze
# 48    ablaze
# 49    ablaze
# Name: keyword, dtype: object

# %%
train['text'][49]
# Out:
# "First night with retainers in. It's quite weird. Better get used to it; I have to wear them every single night for the next year at least."

# %%
train['text'][0]
# Out:
# 'Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all'

# %%
train['keyword'].value_counts().head(10)
# Out:
# fatalities     45
# deluge         42
# armageddon     42
# harm           41
# body%20bags    41
# sinking        41
# damage         41
# fear           40
# evacuate       40
# twister        40
# Name: keyword, dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='keyword',data=train)

# %%
train['keyword'].nunique()
# Out:
# 221

# %%
train['keyword'].value_counts().head(20)
# Out:
# fatalities     45
# deluge         42
# armageddon     42
# harm           41
# body%20bags    41
# sinking        41
# damage         41
# fear           40
# evacuate       40
# twister        40
# collided       40
# siren          40
# windstorm      40
# outbreak       40
# earthquake     39
# flames         39
# derailment     39
# hellfire       39
# explosion      39
# famine         39
# Name: keyword, dtype: int64

# %%
train['text'][55]
# Out:
# '#Kurds trampling on Turkmen flag later set it ablaze while others vandalized offices of Turkmen Front in #Diyala http://t.co/4IzFdYC3cg'

# %%
train['keyword'].value_counts().head(12)
# Out:
# fatalities     45
# deluge         42
# armageddon     42
# harm           41
# body%20bags    41
# sinking        41
# damage         41
# fear           40
# evacuate       40
# twister        40
# collided       40
# siren          40
# Name: keyword, dtype: int64

# %%
train['keyword'].dropna(inplace=True)

# %%
train.isnull().sum()
# Out:
# id          0
# keyword    61
# text        0
# target      0
# dtype: int64

# %%
train['keyword']
# Out:
# 31       ablaze
# 32       ablaze
# 33       ablaze
# 34       ablaze
# 35       ablaze
# 36       ablaze
# 37       ablaze
# 38       ablaze
# 39       ablaze
# 40       ablaze
# 41       ablaze
# 42       ablaze
# 43       ablaze
# 44       ablaze
# 45       ablaze
# 46       ablaze
# 47       ablaze
# 48       ablaze
# 49       ablaze
# 50       ablaze
# 51       ablaze
# 52       ablaze
# 53       ablaze
# 54       ablaze
# 55       ablaze
# 56       ablaze
# 57       ablaze
# 58       ablaze
# 59       ablaze
# 60       ablaze
#          ...
# 7553    wrecked
# 7554    wrecked
# 7555    wrecked
# 7556    wrecked
# 7557    wrecked
# 7558    wrecked
# 7559    wrecked
# 7560    wrecked
# 7561    wrecked
# 7562    wrecked
# 7563    wrecked
# 7564    wrecked
# 7565    wrecked
# 7566    wrecked
# 7567    wrecked
# 7568    wrecked
# 7569    wrecked
# 7570    wrecked
# 7571    wrecked
# 7572    wrecked
# 7573    wrecked
# 7574    wrecked
# 7575    wrecked
# 7576    wrecked
# ...

# %%
train.isnull().sum()
# Out:
# id          0
# keyword    61
# text        0
# target      0
# dtype: int64

# %%
dummies=pd.get_dummies(train.keyword)
dummies
# Out:
#       ablaze  accident  aftershock  airplane%20accident  ambulance  \
# 31         1         0           0                    0          0
# 32         1         0           0                    0          0
# 33         1         0           0                    0          0
# 34         1         0           0                    0          0
# 35         1         0           0                    0          0
# 36         1         0           0                    0          0
# 37         1         0           0                    0          0
# 38         1         0           0                    0          0
# 39         1         0           0                    0          0
# 40         1         0           0                    0          0
# 41         1         0           0                    0          0
# 42         1         0           0                    0          0
# 43         1         0           0                    0          0
# ...

# %%
merged.isnull().sum()

# %%
merged=pd.concat([train,dummies],axis=1)

# %%
merged=pd.concat([train,dummies],axis='columns')

# %%
merged
# Out:
#          id keyword                                               text  \
# 0         1     NaN  Our Deeds are the Reason of this #earthquake M...
# 1         4     NaN             Forest fire near La Ronge Sask. Canada
# 2         5     NaN  All residents asked to 'shelter in place' are ...
# 3         6     NaN  13,000 people receive #wildfires evacuation or...
# 4         7     NaN  Just got sent this photo from Ruby #Alaska as ...
# 5         8     NaN  #RockyFire Update => California Hwy. 20 closed...
# 6        10     NaN  #flood #disaster Heavy rain causes flash flood...
# 7        13     NaN  I'm on top of the hill and I can see a fire in...
# 8        14     NaN  There's an emergency evacuation happening now ...
# 9        15     NaN  I'm afraid that the tornado is coming to our a...
# 10       16     NaN        Three people died from the heat wave so far
# 11       17     NaN  Haha South Tampa is getting flooded hah- WAIT ...
# ...

# %%
merged.drop('keyword',axis=1,inplace=True)

# %%
merged['ablaze'].nunique()
# Out:
# 2

# %%
merged
# Out:
#          id                                               text  target  \
# 0         1  Our Deeds are the Reason of this #earthquake M...       1
# 1         4             Forest fire near La Ronge Sask. Canada       1
# 2         5  All residents asked to 'shelter in place' are ...       1
# 3         6  13,000 people receive #wildfires evacuation or...       1
# 4         7  Just got sent this photo from Ruby #Alaska as ...       1
# 5         8  #RockyFire Update => California Hwy. 20 closed...       1
# 6        10  #flood #disaster Heavy rain causes flash flood...       1
# 7        13  I'm on top of the hill and I can see a fire in...       1
# 8        14  There's an emergency evacuation happening now ...       1
# 9        15  I'm afraid that the tornado is coming to our a...       1
# 10       16        Three people died from the heat wave so far       1
# 11       17  Haha South Tampa is getting flooded hah- WAIT ...       1
# ...

# %%
dummies.isnull().sum()
# Out:
# ablaze                 0
# accident               0
# aftershock             0
# airplane%20accident    0
# ambulance              0
# annihilated            0
# annihilation           0
# apocalypse             0
# armageddon             0
# army                   0
# arson                  0
# arsonist               0
# attack                 0
# attacked               0
# avalanche              0
# battle                 0
# bioterror              0
# bioterrorism           0
# blaze                  0
# blazing                0
# bleeding               0
# blew%20up              0
# blight                 0
# blizzard               0
# blood                  0
# bloody                 0
# blown%20up             0
# body%20bag             0
# body%20bagging         0
# body%20bags            0
#                       ..
# survivors              0
# terrorism              0
# terrorist              0
# threat                 0
# thunder                0
# thunderstorm           0
# ...
